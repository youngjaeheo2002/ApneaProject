# %%
path = "/scratch/alim/overnight_validation/ANNE-PSG231215/20-08-20-21_33_30.C1442.L1215.185/20-08-20-21_33_30.C1442.L1215.185-features.edf"

import mne

raw = mne.io.read_raw_edf(path)
raw.crop(0,3000)
df = raw.to_data_frame()
df.head()
# Out:
# Extracting EDF parameters from /scratch/alim/overnight_validation/ANNE-PSG231215/20-08-20-21_33_30.C1442.L1215.185/20-08-20-21_33_30.C1442.L1215.185-features.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# /tmp/ipykernel_26725/2653625331.py:5: RuntimeWarning: Number of records from the header does not match the file size (perhaps the recording was not stopped before exiting). Inferring from the file size.
#   raw = mne.io.read_raw_edf(path)
# /tmp/ipykernel_26725/2653625331.py:5: RuntimeWarning: Physical range is not defined in following channels:
# PLM_events
#   raw = mne.io.read_raw_edf(path)
#    time  zeroCrossingRate        ecgRaw  ecgProcessed         ecgSQI  \
# 0  0.00      3.699985e+07     71.368521   -176.284047  643831.802457
# 1  0.01      3.699985e+07  -6032.216800  -7599.711284  643831.802457
# 2  0.02      3.699985e+07   5602.742718  -8063.675486  643831.802457
# 3  0.03      3.699985e+07 -11372.853956   3535.429572  643831.802457
# 4  0.04      3.699985e+07  22387.602350  10494.892607  643831.802457
#
#          ppgRaw    ppgFiltered         ppgSQI              x            y  \
# 0 -1.852598e+04     705.909819  999984.740978     -14.536187    37.980011
# 1  6.718172e+09  231941.268025  999984.740978 -975101.739040  1705.579919
# 2  6.715690e+09  389523.882506  999984.740978 -974711.224384  2052.996567
# 3  6.720241e+09  547106.496986  999984.740978 -974237.028016  2469.896544
# 4  6.716517e+09  706401.965972  999984.740978 -973874.407263  2852.054856
#
#    ...          SpO2         RR      RRsqi        PPGamp  PPGampmedian  \
# 0  ...  9.117382e+07 -2000000.0 -2000000.0  1.058878e+09  1.058878e+09
# 1  ...  9.117382e+07 -2000000.0 -2000000.0  1.058878e+09  1.058878e+09
# 2  ...  9.117382e+07 -2000000.0 -2000000.0  1.058878e+09  1.058878e+09
# 3  ...  9.117382e+07 -2000000.0 -2000000.0  1.058878e+09  1.058878e+09
# 4  ...  9.117382e+07 -2000000.0 -2000000.0  1.058878e+09  1.058878e+09
#
#    sleepstage  arousal_events  resp_events     PLM_events  SpO2_events
# 0         0.0             0.0          0.0  500007.629511          0.0
# 1         0.0             0.0          0.0  500007.629511          0.0
# 2         0.0             0.0          0.0  500007.629511          0.0
# 3         0.0             0.0          0.0  500007.629511          0.0
# 4         0.0             0.0          0.0  500007.629511          0.0
#
# [5 rows x 33 columns]
